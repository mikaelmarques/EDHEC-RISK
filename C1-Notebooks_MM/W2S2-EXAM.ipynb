# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import edhec_risk_kit as erk
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# C:\Users\Mikael\Google Drive\EDHEC Financial Modeling Python\edhec_risk_kit_125.py:34: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if filetype is "returns":
# C:\Users\Mikael\Google Drive\EDHEC Financial Modeling Python\edhec_risk_kit_125.py:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif filetype is "nfirms":
# C:\Users\Mikael\Google Drive\EDHEC Financial Modeling Python\edhec_risk_kit_125.py:40: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif filetype is "size":

# %%
hf = erk.get_hfi_returns()
hf_2000 = hf['2000':]
erk.var_gaussian(hf_2000['Distressed Securities'], level=1)
# Out:
# 0.03143017693928047

# %%
erk.var_gaussian(hf_2000['Distressed Securities'], level=1, modified=True)
# Out:
# 0.04913697002361339

# %%
erk.var_historic(hf_2000['Distressed Securities'], level=1)
# Out:
# 0.042642

# %%
ind = erk.get_ind_returns()
ind_2005 = ind['2013':'2017'][['Books', 'Steel', 'Oil', 'Mines']]
ind_2005
# Out:
#           Books   Steel     Oil   Mines
# 2013-01  0.0513  0.0428  0.0788  0.0059
# 2013-02 -0.0654 -0.0268  0.0052 -0.0756
# 2013-03  0.0778  0.0210  0.0209  0.0091
# 2013-04 -0.0029 -0.0441 -0.0129 -0.1057
# 2013-05  0.0479  0.0384  0.0307  0.0022
# 2013-06  0.0246 -0.0472 -0.0211 -0.0959
# 2013-07  0.1207  0.0697  0.0496  0.0002
# 2013-08 -0.0488 -0.0275 -0.0193  0.0459
# 2013-09  0.0626  0.0835  0.0189  0.0116
# 2013-10  0.0718  0.0838  0.0472  0.0534
# 2013-11  0.0021  0.0172  0.0098 -0.0558
# 2013-12  0.0775  0.0652  0.0290  0.0684
# 2014-01 -0.0712 -0.0547 -0.0703 -0.0643
# 2014-02  0.0673  0.0255  0.0571  0.0656
# 2014-03 -0.0075  0.0367  0.0251 -0.0064
# 2014-04 -0.0209  0.0065  0.0564  0.0294
# 2014-05 -0.0153 -0.0162  0.0096 -0.0217
# 2014-06  0.0880  0.0489  0.0416  0.0629
# 2014-07 -0.0160  0.0220 -0.0349  0.0193
# 2014-08  0.0264  0.0621  0.0225  0.0134
# 2014-09 -0.0729 -0.0479 -0.0798 -0.1077
# 2014-10  0.0328  0.0217 -0.0447 -0.0928
# ...

# %%
rf = 0.1
er = erk.annualize_rets(ind_2005, 12)
cov = ind_2005.cov()
er
# Out:
# Books    0.095312
# Steel    0.100716
# Oil      0.025275
# Mines    0.005136
# dtype: float64

# %%
cov
# Out:
#           Books     Steel       Oil     Mines
# Books  0.002720  0.001940  0.001637  0.001539
# Steel  0.001940  0.004391  0.002122  0.003391
# Oil    0.001637  0.002122  0.002697  0.002179
# Mines  0.001539  0.003391  0.002179  0.005232

# %%
w_msr = erk.msr(0.1, er, cov)
w_msr.round(3)
# Out:
# array([0., 1., 0., 0.])

# %%
w_gmv = erk.gmv(cov)
w_gmv
# Out:
# array([0.47702487, 0.        , 0.43411203, 0.0888631 ])

# %%
erk.portfolio_vol(w_msr, ind['2018'][['Books', 'Steel', 'Oil', 'Mines']].cov())*12**0.5
# Out:
# 0.21983988181484188

# %%
erk.portfolio_vol(w_gmv, ind['2018'][['Books', 'Steel', 'Oil', 'Mines']].cov())*12**0.5
# Out:
# 0.18973734520184568
